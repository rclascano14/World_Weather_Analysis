# %%
# Import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import sys
sys.path.append('..')
from config import weather_api_key
import requests

# %%
# Create set of 2,000 latitudes and longitudes
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)
# Zip both lists and extract to a list of coordinates
coords = list(zip(lats,lngs))

# %%
# Initialize cities list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    
    # If the city is unique, then we will add it to the cities list.
    if (city,country) not in cities:
        cities.append((city,country))

# %%
# Check the number of cities
len(cities)
# Out:
# 772

# %%
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | punta arenas
# Processing Record 2 of the Set 1 | bengkulu
# Processing Record 3 of the Set 1 | ourossogui
# Processing Record 4 of the Set 1 | doume
# Processing Record 5 of the Set 1 | sambava
# Processing Record 6 of the Set 1 | arlit
# Processing Record 7 of the Set 1 | tyrma
# Processing Record 8 of the Set 1 | hobart
# Processing Record 9 of the Set 1 | busselton
# Processing Record 10 of the Set 1 | rikitea
# Processing Record 11 of the Set 1 | ilulissat
# Processing Record 12 of the Set 1 | sitka
# Processing Record 13 of the Set 1 | ginir
# Processing Record 14 of the Set 1 | victoria
# Processing Record 15 of the Set 1 | atuona
# Processing Record 16 of the Set 1 | saint george
# Processing Record 17 of the Set 1 | totton
# Processing Record 18 of the Set 1 | semey
# Processing Record 19 of the Set 1 | longyearbyen
# Processing Record 20 of the Set 1 | lebu
# Processing Record 21 of the Set 1 | tiksi
# Processing Record 22 of the Set 1 | fortuna
# Processing Record 23 of the Set 1 | hlotse
# Processing Record 24 of the Set 1 | san rafael del sur
# Processing Record 25 of the Set 1 | paita
# Processing Record 26 of the Set 1 | conceicao do araguaia
# Processing Record 27 of the Set 1 | clyde river
# Processing Record 28 of the Set 1 | fairbanks
# Processing Record 29 of the Set 1 | otradnoye
# Processing Record 30 of the Set 1 | kodiak
# Processing Record 31 of the Set 1 | rio gallegos
# Processing Record 32 of the Set 1 | banda aceh
# Processing Record 33 of the Set 1 | kaitangata
# Processing Record 34 of the Set 1 | maceio
# Processing Record 35 of the Set 1 | tarudant
# City not found. Skipping...
# Processing Record 36 of the Set 1 | reefton
# Processing Record 37 of the Set 1 | bredasdorp
# Processing Record 38 of the Set 1 | mataura
# Processing Record 39 of the Set 1 | kapaa
# Processing Record 40 of the Set 1 | zhangye
# Processing Record 41 of the Set 1 | mar del plata
# Processing Record 42 of the Set 1 | cabo san lucas
# Processing Record 43 of the Set 1 | yellowknife
# Processing Record 44 of the Set 1 | jackson
# Processing Record 45 of the Set 1 | alofi
# Processing Record 46 of the Set 1 | hermanus
# Processing Record 47 of the Set 1 | georgetown
# Processing Record 48 of the Set 1 | severo-kurilsk
# Processing Record 49 of the Set 1 | cape town
# Processing Record 50 of the Set 1 | vestmannaeyjar
# Processing Record 1 of the Set 2 | san patricio
# Processing Record 2 of the Set 2 | saldanha
# Processing Record 3 of the Set 2 | new norfolk
# Processing Record 4 of the Set 2 | kazalinsk
# Processing Record 5 of the Set 2 | havelock
# Processing Record 6 of the Set 2 | castro
# Processing Record 7 of the Set 2 | nikolskoye
# Processing Record 8 of the Set 2 | souillac
# Processing Record 9 of the Set 2 | nanortalik
# Processing Record 10 of the Set 2 | bilma
# Processing Record 11 of the Set 2 | thai binh
# Processing Record 12 of the Set 2 | omboue
# Processing Record 13 of the Set 2 | qaanaaq
# Processing Record 14 of the Set 2 | torbay
# Processing Record 15 of the Set 2 | luderitz
# Processing Record 16 of the Set 2 | san quintin
# Processing Record 17 of the Set 2 | barrow
# Processing Record 18 of the Set 2 | arraial do cabo
# Processing Record 19 of the Set 2 | attawapiskat
# Processing Record 20 of the Set 2 | alice springs
# Processing Record 21 of the Set 2 | presidente prudente
# Processing Record 22 of the Set 2 | bluff
# Processing Record 23 of the Set 2 | bathsheba
# Processing Record 24 of the Set 2 | tessalit
# Processing Record 25 of the Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 26 of the Set 2 | illoqqortoormiut
# Processing Record 27 of the Set 2 | uniontown
# Processing Record 28 of the Set 2 | ribeira grande
# Processing Record 29 of the Set 2 | belushya guba
# Processing Record 30 of the Set 2 | ancud
# Processing Record 31 of the Set 2 | mantua
# Processing Record 32 of the Set 2 | port alfred
# Processing Record 33 of the Set 2 | lorengau
# Processing Record 34 of the Set 2 | lagoa
# Processing Record 35 of the Set 2 | albany
# Processing Record 36 of the Set 2 | chokurdakh
# Processing Record 37 of the Set 2 | upernavik
# Processing Record 38 of the Set 2 | sentyabrskiy
# Processing Record 39 of the Set 2 | nanakuli
# Processing Record 40 of the Set 2 | mahebourg
# Processing Record 41 of the Set 2 | pacific grove
# Processing Record 42 of the Set 2 | sorvag
# City not found. Skipping...
# Processing Record 43 of the Set 2 | dudinka
# Processing Record 44 of the Set 2 | ushuaia
# Processing Record 45 of the Set 2 | nyagan
# Processing Record 46 of the Set 2 | arman
# Processing Record 47 of the Set 2 | zabaykalsk
# Processing Record 48 of the Set 2 | ostrovnoy
# Processing Record 49 of the Set 2 | henties bay
# Processing Record 50 of the Set 2 | robstown
# Processing Record 1 of the Set 3 | bambous virieux
# Processing Record 2 of the Set 3 | peniche
# Processing Record 3 of the Set 3 | avarua
# Processing Record 4 of the Set 3 | frederico westphalen
# Processing Record 5 of the Set 3 | vaini
# Processing Record 6 of the Set 3 | thurso
# Processing Record 7 of the Set 3 | norman wells
# Processing Record 8 of the Set 3 | pallasovka
# Processing Record 9 of the Set 3 | jamestown
# Processing Record 10 of the Set 3 | priladozhskiy
# Processing Record 11 of the Set 3 | burnie
# Processing Record 12 of the Set 3 | yulara
# Processing Record 13 of the Set 3 | indi
# Processing Record 14 of the Set 3 | omsukchan
# Processing Record 15 of the Set 3 | gogrial
# Processing Record 16 of the Set 3 | clifton springs
# Processing Record 17 of the Set 3 | tres arroyos
# Processing Record 18 of the Set 3 | lanxi
# Processing Record 19 of the Set 3 | hithadhoo
# Processing Record 20 of the Set 3 | tuktoyaktuk
# Processing Record 21 of the Set 3 | samusu
# City not found. Skipping...
# Processing Record 22 of the Set 3 | naze
# Processing Record 23 of the Set 3 | lishui
# Processing Record 24 of the Set 3 | cidreira
# Processing Record 25 of the Set 3 | touros
# Processing Record 26 of the Set 3 | sinnamary
# Processing Record 27 of the Set 3 | neftegorsk
# Processing Record 28 of the Set 3 | port elizabeth
# Processing Record 29 of the Set 3 | kijang
# Processing Record 30 of the Set 3 | clearwater
# Processing Record 31 of the Set 3 | kusti
# Processing Record 32 of the Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 33 of the Set 3 | galiwinku
# Processing Record 34 of the Set 3 | twentynine palms
# Processing Record 35 of the Set 3 | port hawkesbury
# Processing Record 36 of the Set 3 | ko samui
# Processing Record 37 of the Set 3 | xinzhou
# Processing Record 38 of the Set 3 | nikolayevsk-na-amure
# Processing Record 39 of the Set 3 | opobo
# City not found. Skipping...
# Processing Record 40 of the Set 3 | laguna
# Processing Record 41 of the Set 3 | mana
# Processing Record 42 of the Set 3 | katsuura
# Processing Record 43 of the Set 3 | soverato
# Processing Record 44 of the Set 3 | butaritari
# Processing Record 45 of the Set 3 | namibe
# Processing Record 46 of the Set 3 | mbaiki
# Processing Record 47 of the Set 3 | verkh-suetka
# Processing Record 48 of the Set 3 | khorixas
# Processing Record 49 of the Set 3 | saskylakh
# Processing Record 50 of the Set 3 | shirokiy
# Processing Record 1 of the Set 4 | faya
# Processing Record 2 of the Set 4 | thompson
# Processing Record 3 of the Set 4 | morondava
# City not found. Skipping...
# Processing Record 4 of the Set 4 | palabuhanratu
# Processing Record 5 of the Set 4 | khao wong
# Processing Record 6 of the Set 4 | meulaboh
# Processing Record 7 of the Set 4 | abu samrah
# Processing Record 8 of the Set 4 | alta floresta
# Processing Record 9 of the Set 4 | khatanga
# Processing Record 10 of the Set 4 | rimouski
# Processing Record 11 of the Set 4 | itaituba
# Processing Record 12 of the Set 4 | skjervoy
# Processing Record 13 of the Set 4 | saquarema
# Processing Record 14 of the Set 4 | tazovskiy
# Processing Record 15 of the Set 4 | iqaluit
# Processing Record 16 of the Set 4 | almaty
# Processing Record 17 of the Set 4 | kharp
# Processing Record 18 of the Set 4 | hilo
# Processing Record 19 of the Set 4 | leningradskiy
# Processing Record 20 of the Set 4 | evensk
# Processing Record 21 of the Set 4 | port lincoln
# Processing Record 22 of the Set 4 | yaan
# Processing Record 23 of the Set 4 | pevek
# Processing Record 24 of the Set 4 | port macquarie
# Processing Record 25 of the Set 4 | mogok
# Processing Record 26 of the Set 4 | shieli
# Processing Record 27 of the Set 4 | carnarvon
# Processing Record 28 of the Set 4 | avera
# Processing Record 29 of the Set 4 | fuerte olimpo
# Processing Record 30 of the Set 4 | asau
# Processing Record 31 of the Set 4 | penzance
# Processing Record 32 of the Set 4 | bandarbeyla
# Processing Record 33 of the Set 4 | zambezi
# Processing Record 34 of the Set 4 | beitbridge
# Processing Record 35 of the Set 4 | pokhara
# Processing Record 36 of the Set 4 | lata
# Processing Record 37 of the Set 4 | iberia
# Processing Record 38 of the Set 4 | yenagoa
# City not found. Skipping...
# Processing Record 39 of the Set 4 | pangnirtung
# Processing Record 40 of the Set 4 | mabopane
# Processing Record 41 of the Set 4 | puerto ayora
# Processing Record 42 of the Set 4 | tasiilaq
# Processing Record 43 of the Set 4 | yamoussoukro
# Processing Record 44 of the Set 4 | vila velha
# Processing Record 45 of the Set 4 | coihaique
# Processing Record 46 of the Set 4 | codrington
# Processing Record 47 of the Set 4 | saint-georges
# Processing Record 48 of the Set 4 | cherskiy
# Processing Record 49 of the Set 4 | kargat
# Processing Record 50 of the Set 4 | yanchukan
# Processing Record 1 of the Set 5 | noyabrsk
# Processing Record 2 of the Set 5 | constitucion
# Processing Record 3 of the Set 5 | ixtapa
# Processing Record 4 of the Set 5 | novaya zaimka
# Processing Record 5 of the Set 5 | warqla
# City not found. Skipping...
# Processing Record 6 of the Set 5 | bolshiye uki
# Processing Record 7 of the Set 5 | gigmoto
# Processing Record 8 of the Set 5 | elie
# Processing Record 9 of the Set 5 | totness
# Processing Record 10 of the Set 5 | rio grande
# Processing Record 11 of the Set 5 | barentsburg
# Processing Record 12 of the Set 5 | gurgan
# City not found. Skipping...
# Processing Record 13 of the Set 5 | east london
# Processing Record 14 of the Set 5 | owando
# Processing Record 15 of the Set 5 | penhold
# Processing Record 16 of the Set 5 | dunedin
# Processing Record 17 of the Set 5 | aksu
# Processing Record 18 of the Set 5 | klaksvik
# City not found. Skipping...
# Processing Record 19 of the Set 5 | rincon
# Processing Record 20 of the Set 5 | necocli
# Processing Record 21 of the Set 5 | leshukonskoye
# Processing Record 22 of the Set 5 | ponta do sol
# Processing Record 23 of the Set 5 | saleaula
# City not found. Skipping...
# Processing Record 24 of the Set 5 | chapais
# Processing Record 25 of the Set 5 | hobyo
# Processing Record 26 of the Set 5 | pimenta bueno
# Processing Record 27 of the Set 5 | faanui
# Processing Record 28 of the Set 5 | buritis
# Processing Record 29 of the Set 5 | kokkola
# Processing Record 30 of the Set 5 | san cristobal
# Processing Record 31 of the Set 5 | saint anthony
# Processing Record 32 of the Set 5 | kaset sombun
# Processing Record 33 of the Set 5 | cockburn town
# Processing Record 34 of the Set 5 | belmonte
# Processing Record 35 of the Set 5 | sao joao da barra
# Processing Record 36 of the Set 5 | djibo
# Processing Record 37 of the Set 5 | hofn
# Processing Record 38 of the Set 5 | esperance
# Processing Record 39 of the Set 5 | portland
# Processing Record 40 of the Set 5 | pierre
# Processing Record 41 of the Set 5 | bulgan
# Processing Record 42 of the Set 5 | merano
# Processing Record 43 of the Set 5 | saint-philippe
# Processing Record 44 of the Set 5 | mingguang
# Processing Record 45 of the Set 5 | emerald
# Processing Record 46 of the Set 5 | mehamn
# Processing Record 47 of the Set 5 | cayenne
# Processing Record 48 of the Set 5 | sumbe
# Processing Record 49 of the Set 5 | san jose
# Processing Record 50 of the Set 5 | itarema
# Processing Record 1 of the Set 6 | trairi
# Processing Record 2 of the Set 6 | piopio
# Processing Record 3 of the Set 6 | comitan
# Processing Record 4 of the Set 6 | lukovetskiy
# Processing Record 5 of the Set 6 | sabang
# Processing Record 6 of the Set 6 | saint-pierre
# Processing Record 7 of the Set 6 | acarau
# Processing Record 8 of the Set 6 | roebourne
# Processing Record 9 of the Set 6 | amderma
# Processing Record 10 of the Set 6 | keshan
# Processing Record 11 of the Set 6 | taoudenni
# Processing Record 12 of the Set 6 | colomi
# Processing Record 13 of the Set 6 | yining
# Processing Record 14 of the Set 6 | eureka
# Processing Record 15 of the Set 6 | margate
# Processing Record 16 of the Set 6 | la rioja
# Processing Record 17 of the Set 6 | beohari
# Processing Record 18 of the Set 6 | gweru
# Processing Record 19 of the Set 6 | bakchar
# Processing Record 20 of the Set 6 | kuybyshevo
# Processing Record 21 of the Set 6 | namatanai
# Processing Record 22 of the Set 6 | verkhnyaya inta
# Processing Record 23 of the Set 6 | xingcheng
# Processing Record 24 of the Set 6 | maumere
# Processing Record 25 of the Set 6 | kachiry
# Processing Record 26 of the Set 6 | lengshuitan
# Processing Record 27 of the Set 6 | lucapa
# Processing Record 28 of the Set 6 | kerekegyhaza
# Processing Record 29 of the Set 6 | cedar city
# Processing Record 30 of the Set 6 | nome
# Processing Record 31 of the Set 6 | chabahar
# Processing Record 32 of the Set 6 | alberton
# Processing Record 33 of the Set 6 | akom
# Processing Record 34 of the Set 6 | kutum
# Processing Record 35 of the Set 6 | guerrero negro
# Processing Record 36 of the Set 6 | washington
# Processing Record 37 of the Set 6 | gamba
# Processing Record 38 of the Set 6 | nehe
# Processing Record 39 of the Set 6 | kavieng
# Processing Record 40 of the Set 6 | mirnyy
# Processing Record 41 of the Set 6 | rio branco do sul
# Processing Record 42 of the Set 6 | collierville
# Processing Record 43 of the Set 6 | limulunga
# Processing Record 44 of the Set 6 | naryan-mar
# Processing Record 45 of the Set 6 | bintulu
# Processing Record 46 of the Set 6 | kralendijk
# Processing Record 47 of the Set 6 | reconquista
# Processing Record 48 of the Set 6 | beloha
# City not found. Skipping...
# Processing Record 49 of the Set 6 | brzeziny
# Processing Record 50 of the Set 6 | nouadhibou
# Processing Record 1 of the Set 7 | olafsvik
# Processing Record 2 of the Set 7 | los llanos de aridane
# Processing Record 3 of the Set 7 | sohbatpur
# Processing Record 4 of the Set 7 | srednekolymsk
# Processing Record 5 of the Set 7 | nizhneyansk
# Processing Record 6 of the Set 7 | chuy
# Processing Record 7 of the Set 7 | kruisfontein
# Processing Record 8 of the Set 7 | de aar
# Processing Record 9 of the Set 7 | takaka
# Processing Record 10 of the Set 7 | brae
# Processing Record 11 of the Set 7 | yumen
# Processing Record 12 of the Set 7 | dingzhou
# Processing Record 13 of the Set 7 | dyersburg
# Processing Record 14 of the Set 7 | sistranda
# Processing Record 15 of the Set 7 | komsomolskiy
# Processing Record 16 of the Set 7 | oranjestad
# Processing Record 17 of the Set 7 | puerto escondido
# Processing Record 18 of the Set 7 | muros
# Processing Record 19 of the Set 7 | gualeguay
# Processing Record 20 of the Set 7 | dingle
# Processing Record 21 of the Set 7 | lensk
# Processing Record 22 of the Set 7 | labutta
# Processing Record 23 of the Set 7 | ayagoz
# Processing Record 24 of the Set 7 | kochevo
# Processing Record 25 of the Set 7 | dikson
# Processing Record 26 of the Set 7 | port pirie
# Processing Record 27 of the Set 7 | bairiki
# Processing Record 28 of the Set 7 | kilindoni
# Processing Record 29 of the Set 7 | shimoda
# Processing Record 30 of the Set 7 | marawi
# Processing Record 31 of the Set 7 | sayyan
# Processing Record 32 of the Set 7 | mitzic
# Processing Record 33 of the Set 7 | denizli
# Processing Record 34 of the Set 7 | sicuani
# Processing Record 35 of the Set 7 | russell
# Processing Record 36 of the Set 7 | puga
# Processing Record 37 of the Set 7 | mugur-aksy
# Processing Record 38 of the Set 7 | talnakh
# Processing Record 39 of the Set 7 | tual
# Processing Record 40 of the Set 7 | burica
# City not found. Skipping...
# Processing Record 41 of the Set 7 | wukari
# City not found. Skipping...
# Processing Record 42 of the Set 7 | safaga
# Processing Record 43 of the Set 7 | damphu
# Processing Record 44 of the Set 7 | lasa
# Processing Record 45 of the Set 7 | berlevag
# Processing Record 46 of the Set 7 | porgera
# Processing Record 47 of the Set 7 | sindor
# Processing Record 48 of the Set 7 | samarai
# Processing Record 49 of the Set 7 | podporozhye
# Processing Record 50 of the Set 7 | dzilam gonzalez
# Processing Record 1 of the Set 8 | sabancuy
# Processing Record 2 of the Set 8 | shache
# Processing Record 3 of the Set 8 | zhoucun
# Processing Record 4 of the Set 8 | manokwari
# Processing Record 5 of the Set 8 | vanavara
# Processing Record 6 of the Set 8 | pombas
# Processing Record 7 of the Set 8 | hambantota
# Processing Record 8 of the Set 8 | vostok
# Processing Record 9 of the Set 8 | kahului
# Processing Record 10 of the Set 8 | nicolas bravo
# Processing Record 11 of the Set 8 | dulce nombre de culmi
# Processing Record 12 of the Set 8 | conde
# Processing Record 13 of the Set 8 | krupka
# Processing Record 14 of the Set 8 | bourail
# Processing Record 15 of the Set 8 | havoysund
# Processing Record 16 of the Set 8 | vuktyl
# Processing Record 17 of the Set 8 | marcona
# Processing Record 18 of the Set 8 | wulanhaote
# Processing Record 19 of the Set 8 | galesong
# Processing Record 20 of the Set 8 | urumqi
# Processing Record 21 of the Set 8 | vila franca do campo
# Processing Record 22 of the Set 8 | waddan
# Processing Record 23 of the Set 8 | mae hong son
# Processing Record 24 of the Set 8 | sur
# Processing Record 25 of the Set 8 | beringovskiy
# Processing Record 26 of the Set 8 | lokoja
# City not found. Skipping...
# Processing Record 27 of the Set 8 | soma
# Processing Record 28 of the Set 8 | port hedland
# Processing Record 29 of the Set 8 | bonthe
# Processing Record 30 of the Set 8 | coquimbo
# Processing Record 31 of the Set 8 | marsh harbour
# Processing Record 32 of the Set 8 | krasnoselkup
# Processing Record 33 of the Set 8 | san juan
# Processing Record 34 of the Set 8 | bauchi
# City not found. Skipping...
# Processing Record 35 of the Set 8 | pochutla
# Processing Record 36 of the Set 8 | loa janan
# Processing Record 37 of the Set 8 | san jose de ocoa
# Processing Record 38 of the Set 8 | mys shmidta
# Processing Record 39 of the Set 8 | poum
# Processing Record 40 of the Set 8 | fereydunshahr
# Processing Record 41 of the Set 8 | opuwo
# Processing Record 42 of the Set 8 | road town
# Processing Record 43 of the Set 8 | hagere hiywet
# Processing Record 44 of the Set 8 | moose factory
# Processing Record 45 of the Set 8 | puerto cabello
# Processing Record 46 of the Set 8 | parangan
# Processing Record 47 of the Set 8 | kakonko
# Processing Record 48 of the Set 8 | mahon
# Processing Record 49 of the Set 8 | brandfort
# Processing Record 50 of the Set 8 | beipiao
# Processing Record 1 of the Set 9 | winnemucca
# Processing Record 2 of the Set 9 | iracoubo
# Processing Record 3 of the Set 9 | pueblo nuevo solistahuacan
# Processing Record 4 of the Set 9 | padang
# Processing Record 5 of the Set 9 | praya
# Processing Record 6 of the Set 9 | xiangxiang
# Processing Record 7 of the Set 9 | la ronge
# Processing Record 8 of the Set 9 | kawalu
# Processing Record 9 of the Set 9 | bethel
# Processing Record 10 of the Set 9 | goulburn
# Processing Record 11 of the Set 9 | dezful
# Processing Record 12 of the Set 9 | kaeo
# Processing Record 13 of the Set 9 | suphan buri
# Processing Record 14 of the Set 9 | sampit
# Processing Record 15 of the Set 9 | acapulco
# Processing Record 16 of the Set 9 | seoul
# Processing Record 17 of the Set 9 | concordia
# Processing Record 18 of the Set 9 | marystown
# Processing Record 19 of the Set 9 | praia da vitoria
# Processing Record 20 of the Set 9 | gunjur
# Processing Record 21 of the Set 9 | houma
# Processing Record 22 of the Set 9 | kavaratti
# Processing Record 23 of the Set 9 | yambio
# Processing Record 24 of the Set 9 | marzuq
# Processing Record 25 of the Set 9 | gat
# Processing Record 26 of the Set 9 | wielun
# Processing Record 27 of the Set 9 | nagornyy
# Processing Record 28 of the Set 9 | camacha
# Processing Record 29 of the Set 9 | sao filipe
# Processing Record 30 of the Set 9 | oranjestad
# Processing Record 31 of the Set 9 | andros town
# Processing Record 32 of the Set 9 | adrar
# City not found. Skipping...
# Processing Record 33 of the Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 34 of the Set 9 | neiva
# Processing Record 35 of the Set 9 | brokopondo
# Processing Record 36 of the Set 9 | acari
# Processing Record 37 of the Set 9 | port hardy
# Processing Record 38 of the Set 9 | san-pedro
# Processing Record 39 of the Set 9 | grand gaube
# Processing Record 40 of the Set 9 | valdivia
# Processing Record 41 of the Set 9 | aljezur
# Processing Record 42 of the Set 9 | katav-ivanovsk
# Processing Record 43 of the Set 9 | hunza
# Processing Record 44 of the Set 9 | nishihara
# Processing Record 45 of the Set 9 | fare
# Processing Record 46 of the Set 9 | abadan
# Processing Record 47 of the Set 9 | rungata
# Processing Record 48 of the Set 9 | karasburg
# Processing Record 49 of the Set 9 | khonuu
# Processing Record 50 of the Set 9 | leh
# Processing Record 1 of the Set 10 | davenda
# Processing Record 2 of the Set 10 | sorong
# Processing Record 3 of the Set 10 | lompoc
# Processing Record 4 of the Set 10 | manhuacu
# Processing Record 5 of the Set 10 | torata
# Processing Record 6 of the Set 10 | warwick
# Processing Record 7 of the Set 10 | tabory
# Processing Record 8 of the Set 10 | ndele
# Processing Record 9 of the Set 10 | ruteng
# Processing Record 10 of the Set 10 | green river
# Processing Record 11 of the Set 10 | hihifo
# Processing Record 12 of the Set 10 | brattleboro
# Processing Record 13 of the Set 10 | launceston
# Processing Record 14 of the Set 10 | provideniya
# Processing Record 15 of the Set 10 | hare bay
# Processing Record 16 of the Set 10 | warri
# City not found. Skipping...
# Processing Record 17 of the Set 10 | nyurba
# Processing Record 18 of the Set 10 | ishigaki
# Processing Record 19 of the Set 10 | karaul
# Processing Record 20 of the Set 10 | mattru
# Processing Record 21 of the Set 10 | ola
# Processing Record 22 of the Set 10 | kimbe
# Processing Record 23 of the Set 10 | wanning
# Processing Record 24 of the Set 10 | turukhansk
# Processing Record 25 of the Set 10 | srbac
# Processing Record 26 of the Set 10 | nurota
# Processing Record 27 of the Set 10 | waingapu
# Processing Record 28 of the Set 10 | kapit
# Processing Record 29 of the Set 10 | cap malheureux
# Processing Record 30 of the Set 10 | tongliao
# Processing Record 31 of the Set 10 | matane
# Processing Record 32 of the Set 10 | geraldton
# Processing Record 33 of the Set 10 | massaguet
# Processing Record 34 of the Set 10 | shamary
# Processing Record 35 of the Set 10 | abu kamal
# Processing Record 36 of the Set 10 | letterkenny
# Processing Record 37 of the Set 10 | yerbogachen
# Processing Record 38 of the Set 10 | ahuimanu
# Processing Record 39 of the Set 10 | kirakira
# Processing Record 40 of the Set 10 | macia
# Processing Record 41 of the Set 10 | elizabeth city
# Processing Record 42 of the Set 10 | broken hill
# Processing Record 43 of the Set 10 | helsinki
# Processing Record 44 of the Set 10 | platteville
# Processing Record 45 of the Set 10 | kosonsoy
# Processing Record 46 of the Set 10 | hamilton
# Processing Record 47 of the Set 10 | ulaangom
# Processing Record 48 of the Set 10 | inuvik
# Processing Record 49 of the Set 10 | homer
# Processing Record 50 of the Set 10 | sokoni
# Processing Record 1 of the Set 11 | enid
# Processing Record 2 of the Set 11 | meyungs
# City not found. Skipping...
# Processing Record 3 of the Set 11 | anadyr
# Processing Record 4 of the Set 11 | rawson
# Processing Record 5 of the Set 11 | atambua
# Processing Record 6 of the Set 11 | saint-augustin
# Processing Record 7 of the Set 11 | arkhangelsk
# Processing Record 8 of the Set 11 | buloh kasap
# Processing Record 9 of the Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 10 of the Set 11 | benjamin constant
# Processing Record 11 of the Set 11 | takefu
# Processing Record 12 of the Set 11 | perelyub
# Processing Record 13 of the Set 11 | peretu
# Processing Record 14 of the Set 11 | umm jarr
# Processing Record 15 of the Set 11 | sao raimundo nonato
# Processing Record 16 of the Set 11 | carros
# Processing Record 17 of the Set 11 | half moon bay
# Processing Record 18 of the Set 11 | ust-nera
# Processing Record 19 of the Set 11 | zhigansk
# Processing Record 20 of the Set 11 | maues
# Processing Record 21 of the Set 11 | japura
# Processing Record 22 of the Set 11 | sao desiderio
# Processing Record 23 of the Set 11 | haines junction
# Processing Record 24 of the Set 11 | banjar
# Processing Record 25 of the Set 11 | artyk
# Processing Record 26 of the Set 11 | sarkand
# Processing Record 27 of the Set 11 | mount gambier
# Processing Record 28 of the Set 11 | castelo do piaui
# Processing Record 29 of the Set 11 | manono
# Processing Record 30 of the Set 11 | shelui
# Processing Record 31 of the Set 11 | pangai
# Processing Record 32 of the Set 11 | tumannyy
# Processing Record 33 of the Set 11 | ziway
# Processing Record 34 of the Set 11 | tandalti
# Processing Record 35 of the Set 11 | resistencia
# Processing Record 36 of the Set 11 | biak
# Processing Record 37 of the Set 11 | nuuk
# Processing Record 38 of the Set 11 | kudahuvadhoo
# Processing Record 39 of the Set 11 | atasu
# Processing Record 40 of the Set 11 | yar-sale
# Processing Record 41 of the Set 11 | marsa matruh
# Processing Record 42 of the Set 11 | miracema do tocantins
# Processing Record 43 of the Set 11 | kashan
# Processing Record 44 of the Set 11 | pavilosta
# Processing Record 45 of the Set 11 | hervey bay
# Processing Record 46 of the Set 11 | pont-a-mousson
# Processing Record 47 of the Set 11 | baykit
# Processing Record 48 of the Set 11 | diffa
# Processing Record 49 of the Set 11 | zeya
# Processing Record 50 of the Set 11 | wiarton
# Processing Record 1 of the Set 12 | caravelas
# Processing Record 2 of the Set 12 | mayo
# Processing Record 3 of the Set 12 | urucara
# Processing Record 4 of the Set 12 | colombo
# Processing Record 5 of the Set 12 | sento se
# Processing Record 6 of the Set 12 | iowa city
# Processing Record 7 of the Set 12 | nakhon ratchasima
# Processing Record 8 of the Set 12 | hagen
# Processing Record 9 of the Set 12 | warrenton
# Processing Record 10 of the Set 12 | formoso do araguaia
# Processing Record 11 of the Set 12 | klyuchi
# Processing Record 12 of the Set 12 | montepuez
# Processing Record 13 of the Set 12 | luanda
# Processing Record 14 of the Set 12 | nabire
# Processing Record 15 of the Set 12 | agropoli
# Processing Record 16 of the Set 12 | namtsy
# Processing Record 17 of the Set 12 | kuraymah
# Processing Record 18 of the Set 12 | verkhoyansk
# Processing Record 19 of the Set 12 | bisho
# Processing Record 20 of the Set 12 | turayf
# Processing Record 21 of the Set 12 | lavrentiya
# Processing Record 22 of the Set 12 | dafeng
# Processing Record 23 of the Set 12 | salalah
# Processing Record 24 of the Set 12 | jibuti
# Processing Record 25 of the Set 12 | kuching
# Processing Record 26 of the Set 12 | gallup
# Processing Record 27 of the Set 12 | paamiut
# Processing Record 28 of the Set 12 | grand river south east
# Processing Record 29 of the Set 12 | changli
# Processing Record 30 of the Set 12 | wattegama
# Processing Record 31 of the Set 12 | manzhouli
# Processing Record 32 of the Set 12 | luoyang
# Processing Record 33 of the Set 12 | shahreza
# Processing Record 34 of the Set 12 | udachnyy
# Processing Record 35 of the Set 12 | tyup
# Processing Record 36 of the Set 12 | nova vicosa
# Processing Record 37 of the Set 12 | wenling
# Processing Record 38 of the Set 12 | alice town
# Processing Record 39 of the Set 12 | mangan
# Processing Record 40 of the Set 12 | grootfontein
# Processing Record 41 of the Set 12 | okhotsk
# Processing Record 42 of the Set 12 | saint-joseph
# Processing Record 43 of the Set 12 | makakilo city
# Processing Record 44 of the Set 12 | ust-maya
# Processing Record 45 of the Set 12 | pisco
# Processing Record 46 of the Set 12 | rockhampton
# Processing Record 47 of the Set 12 | kedougou
# Processing Record 48 of the Set 12 | boffa
# Processing Record 49 of the Set 12 | fram
# Processing Record 50 of the Set 12 | teltow
# Processing Record 1 of the Set 13 | milici
# Processing Record 2 of the Set 13 | ucluelet
# Processing Record 3 of the Set 13 | sungai besar
# Processing Record 4 of the Set 13 | gangoh
# Processing Record 5 of the Set 13 | chistoye
# Processing Record 6 of the Set 13 | airai
# City not found. Skipping...
# Processing Record 7 of the Set 13 | qaqortoq
# Processing Record 8 of the Set 13 | sinop
# Processing Record 9 of the Set 13 | mahmudabad
# Processing Record 10 of the Set 13 | asfi
# Processing Record 11 of the Set 13 | alakurtti
# Processing Record 12 of the Set 13 | ritchie
# Processing Record 13 of the Set 13 | antropovo
# Processing Record 14 of the Set 13 | saint-francois
# Processing Record 15 of the Set 13 | flinders
# Processing Record 16 of the Set 13 | tete
# Processing Record 17 of the Set 13 | broome
# Processing Record 18 of the Set 13 | hay river
# Processing Record 19 of the Set 13 | torbat-e jam
# Processing Record 20 of the Set 13 | tsienyane
# City not found. Skipping...
# Processing Record 21 of the Set 13 | acopiara
# Processing Record 22 of the Set 13 | vao
# Processing Record 23 of the Set 13 | forestville
# Processing Record 24 of the Set 13 | hasaki
# Processing Record 25 of the Set 13 | usevya
# Processing Record 26 of the Set 13 | sogdiondon
# Processing Record 27 of the Set 13 | suao
# City not found. Skipping...
# Processing Record 28 of the Set 13 | zaysan
# Processing Record 29 of the Set 13 | salta
# Processing Record 30 of the Set 13 | caruray
# Processing Record 31 of the Set 13 | kazachinskoye
# Processing Record 32 of the Set 13 | mersing
# Processing Record 33 of the Set 13 | noumea
# Processing Record 34 of the Set 13 | amapa
# Processing Record 35 of the Set 13 | ende
# Processing Record 36 of the Set 13 | tuatapere
# Processing Record 37 of the Set 13 | piste
# Processing Record 38 of the Set 13 | nizhniy tsasuchey
# Processing Record 39 of the Set 13 | lachhmangarh
# Processing Record 40 of the Set 13 | narsaq
# Processing Record 41 of the Set 13 | sukhobuzimskoye
# Processing Record 42 of the Set 13 | obo
# Processing Record 43 of the Set 13 | gharghoda
# Processing Record 44 of the Set 13 | kualakapuas
# Processing Record 45 of the Set 13 | college
# Processing Record 46 of the Set 13 | lamu
# Processing Record 47 of the Set 13 | whitehorse
# Processing Record 48 of the Set 13 | maragogi
# Processing Record 49 of the Set 13 | madimba
# Processing Record 50 of the Set 13 | washougal
# Processing Record 1 of the Set 14 | chapada dos guimaraes
# Processing Record 2 of the Set 14 | karauzyak
# Processing Record 3 of the Set 14 | campbell river
# Processing Record 4 of the Set 14 | petropavlovsk-kamchatskiy
# Processing Record 5 of the Set 14 | bury saint edmunds
# Processing Record 6 of the Set 14 | kyabe
# Processing Record 7 of the Set 14 | todos santos
# Processing Record 8 of the Set 14 | derzhavinsk
# Processing Record 9 of the Set 14 | lazaro cardenas
# Processing Record 10 of the Set 14 | east stroudsburg
# Processing Record 11 of the Set 14 | oranjemund
# Processing Record 12 of the Set 14 | cuyo
# Processing Record 13 of the Set 14 | aporawan
# Processing Record 14 of the Set 14 | tahta
# Processing Record 15 of the Set 14 | esfahan
# Processing Record 16 of the Set 14 | paka
# Processing Record 17 of the Set 14 | richards bay
# Processing Record 18 of the Set 14 | brandon
# Processing Record 19 of the Set 14 | berdigestyakh
# Processing Record 20 of the Set 14 | dzerzhinsk
# Processing Record 21 of the Set 14 | araouane
# Processing Record 22 of the Set 14 | bolungarvik
# Processing Record 23 of the Set 14 | alamos
# Processing Record 24 of the Set 14 | bend
# Processing Record 25 of the Set 14 | great falls
# Processing Record 26 of the Set 14 | tairua
# Processing Record 27 of the Set 14 | manadhoo
# Processing Record 28 of the Set 14 | pakokku
# Processing Record 29 of the Set 14 | glamoc
# Processing Record 30 of the Set 14 | ulladulla
# Processing Record 31 of the Set 14 | vallenar
# Processing Record 32 of the Set 14 | kuche
# Processing Record 33 of the Set 14 | gasa
# Processing Record 34 of the Set 14 | sao miguel do araguaia
# Processing Record 35 of the Set 14 | moroni
# Processing Record 36 of the Set 14 | baghdad
# Processing Record 37 of the Set 14 | tabiauea
# Processing Record 38 of the Set 14 | taldan
# Processing Record 39 of the Set 14 | sioux lookout
# Processing Record 40 of the Set 14 | scottsburgh
# Processing Record 41 of the Set 14 | toamasina
# City not found. Skipping...
# Processing Record 42 of the Set 14 | houma
# Processing Record 43 of the Set 14 | sola
# Processing Record 44 of the Set 14 | gobabis
# Processing Record 45 of the Set 14 | mahanoro
# City not found. Skipping...
# Processing Record 46 of the Set 14 | vardo
# Processing Record 47 of the Set 14 | honiara
# Processing Record 48 of the Set 14 | bakal
# Processing Record 49 of the Set 14 | djougou
# Processing Record 50 of the Set 14 | zhanaozen
# Processing Record 1 of the Set 15 | camapua
# Processing Record 2 of the Set 15 | santo angelo
# Processing Record 3 of the Set 15 | redmond
# Processing Record 4 of the Set 15 | dhidhdhoo
# Processing Record 5 of the Set 15 | kirksville
# Processing Record 6 of the Set 15 | bubaque
# Processing Record 7 of the Set 15 | quzhou
# Processing Record 8 of the Set 15 | mount isa
# Processing Record 9 of the Set 15 | saint-paul
# Processing Record 10 of the Set 15 | tateyama
# Processing Record 11 of the Set 15 | mandalgarh
# Processing Record 12 of the Set 15 | pacifica
# Processing Record 13 of the Set 15 | esil
# Processing Record 14 of the Set 15 | fukue
# Processing Record 15 of the Set 15 | kikwit
# Processing Record 16 of the Set 15 | gazimurskiy zavod
# Processing Record 17 of the Set 15 | pontianak
# Processing Record 18 of the Set 15 | malartic
# Processing Record 19 of the Set 15 | harper
# Processing Record 20 of the Set 15 | betare oya
# Processing Record 21 of the Set 15 | tortoli
# Processing Record 22 of the Set 15 | palu
# Processing Record 23 of the Set 15 | lolua
# Processing Record 24 of the Set 15 | hede
# Processing Record 25 of the Set 15 | tecoanapa
# Processing Record 26 of the Set 15 | general roca
# Processing Record 27 of the Set 15 | ternate
# Processing Record 28 of the Set 15 | barranca de upia
# Processing Record 29 of the Set 15 | chiredzi
# Processing Record 30 of the Set 15 | mogadishu
# Processing Record 31 of the Set 15 | mucurapo
# Processing Record 32 of the Set 15 | aswan
# Processing Record 33 of the Set 15 | sakakah
# Processing Record 34 of the Set 15 | hollins
# Processing Record 35 of the Set 15 | parrita
# Processing Record 36 of the Set 15 | ankazoabo
# City not found. Skipping...
# Processing Record 37 of the Set 15 | ozgon
# Processing Record 38 of the Set 15 | walvis bay
# Processing Record 39 of the Set 15 | chapayeve
# Processing Record 40 of the Set 15 | saint-leu
# Processing Record 41 of the Set 15 | champerico
# Processing Record 42 of the Set 15 | gizo
# Processing Record 43 of the Set 15 | ouadda
# Processing Record 44 of the Set 15 | scarborough
# Processing Record 45 of the Set 15 | marrakesh
# Processing Record 46 of the Set 15 | digha
# Processing Record 47 of the Set 15 | requena
# Processing Record 48 of the Set 15 | bom jesus
# Processing Record 49 of the Set 15 | banepa
# Processing Record 50 of the Set 15 | lerwick
# Processing Record 1 of the Set 16 | melissourgoi
# City not found. Skipping...
# Processing Record 2 of the Set 16 | cockburn town
# Processing Record 3 of the Set 16 | pachino
# Processing Record 4 of the Set 16 | muisne
# Processing Record 5 of the Set 16 | bokhan
# Processing Record 6 of the Set 16 | charters towers
# Processing Record 7 of the Set 16 | san pedro de macoris
# Processing Record 8 of the Set 16 | hovd
# Processing Record 9 of the Set 16 | shakiso
# Processing Record 10 of the Set 16 | kesinga
# Processing Record 11 of the Set 16 | roma
# Processing Record 12 of the Set 16 | kailua
# Processing Record 13 of the Set 16 | los angeles
# Processing Record 14 of the Set 16 | serebryansk
# Processing Record 15 of the Set 16 | kununurra
# Processing Record 16 of the Set 16 | ratnagiri
# Processing Record 17 of the Set 16 | husavik
# Processing Record 18 of the Set 16 | buraydah
# Processing Record 19 of the Set 16 | bridlington
# Processing Record 20 of the Set 16 | doha
# Processing Record 21 of the Set 16 | sindand
# City not found. Skipping...
# Processing Record 22 of the Set 16 | taksimo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas      CL -53.1500  -70.9167     51.82        87          75
# 1      Bengkulu      ID  -3.8004  102.2655     75.90        90          99
# 2    Ourossogui      SN  15.6064  -13.3211     85.55        10          93
# 3         Doume      CM   4.2333   13.4500     73.33        33          14
# 4       Sambava      MG -14.2667   50.1667     77.79        80         100
#
#    Wind Speed Current Description
# 0       10.36          light rain
# 1        4.27     overcast clouds
# 2       10.83     overcast clouds
# 3        1.14          few clouds
# 4        4.38     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the dataframe to csv
cities_weather_df.to_csv(output_data_file, index_label="City_ID")
